# %%
import pandas as pd

# %%
# Reading the 2019 dataset 

jan = pd.read_csv("DataSet/Jan19.csv")
janlast = jan.tail(1)
jan = jan[:-1]

feb = pd.read_csv("DataSet/Feb19.csv")
feblast = feb.tail(1)
feb = feb[:-1]
feb.append(janlast, ignore_index = True) 


mar = pd.read_csv("DataSet/Mar19.csv")
marlast = mar.tail(1)
mar = mar[:-1]
mar.append(feblast, ignore_index = True) 



apr = pd.read_csv("DataSet/Apr19.csv")
aprlast = apr.tail(1)
apr = apr[:-1]
apr.append(marlast, ignore_index = True) 


may = pd.read_csv("DataSet/May19.csv")
maylast = may.tail(1)
may = may[:-1]
may.append(aprlast, ignore_index = True) 



jun = pd.read_csv("DataSet/Jun19.csv")
junlast = jun.tail(1)
jun = jun[:-1]
jun.append(maylast, ignore_index = True) 



jul = pd.read_csv("DataSet/Jul19.csv")
jullast = jul.tail(1)
jul = jul[:-1]
jul.append(junlast, ignore_index = True) 



aug = pd.read_csv("DataSet/Aug19.csv")
auglast = aug.tail(1)
aug = aug[:-1]
aug.append(jullast, ignore_index = True) 



sep = pd.read_csv("DataSet/Sep19.csv")
seplast = sep.tail(1)
sep = sep[:-1]
sep.append(auglast, ignore_index = True) 


oct = pd.read_csv("DataSet/Oct19.csv")
octlast = oct.tail(1)
oct = oct[:-1]
oct.append(auglast, ignore_index = True) 



nov = pd.read_csv("DataSet/Nov19.csv")
novlast = nov.tail(1)
nov = nov[:-1]
nov.append(seplast, ignore_index = True) 


dec = pd.read_csv("DataSet/Dec19.csv")
declast = dec.tail(1)
dec = dec[:-1]
dec.append(novlast, ignore_index = True)
# Out:
#      REGION  SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE  Day  Month  Year
# 0      VIC1    1/12/19 0:30      4227.01  41.34      TRADE    1     12  2019
# 1      VIC1    1/12/19 1:00      4128.30  42.50      TRADE    1     12  2019
# 2      VIC1    1/12/19 1:30      3978.96  37.95      TRADE    1     12  2019
# 3      VIC1    1/12/19 2:00      3792.20  19.99      TRADE    1     12  2019
# 4      VIC1    1/12/19 2:30      3711.64  42.50      TRADE    1     12  2019
# ...     ...             ...          ...    ...        ...  ...    ...   ...
# 1483   VIC1  31/12/19 22:00      4129.96  52.91      TRADE   31     12  2019
# 1484   VIC1  31/12/19 22:30      4083.66  58.66      TRADE   31     12  2019
# 1485   VIC1  31/12/19 23:00      4104.95  54.36      TRADE   31     12  2019
# 1486   VIC1  31/12/19 23:30      4325.88  66.87      TRADE   31     12  2019
# 1487   VIC1    1/12/19 0:00      4410.62  50.60      TRADE    1     12  2019
#
# [1488 rows x 8 columns]

# %% [markdown]
# ####################### TIME SERIES FORMAT #######################

# %%
### Time series format

Singlecol_2019 = pd.concat([jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec])

# %%
Singlecol_2019
# Out:
#      REGION  SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE  Day  Month  Year
# 0      VIC1     1/1/19 0:30      4286.24  71.49      TRADE    1      1  2019
# 1      VIC1     1/1/19 1:00      4136.24  72.62      TRADE    1      1  2019
# 2      VIC1     1/1/19 1:30      4049.07  74.28      TRADE    1      1  2019
# 3      VIC1     1/1/19 2:00      3884.78  71.19      TRADE    1      1  2019
# 4      VIC1     1/1/19 2:30      3759.46  67.65      TRADE    1      1  2019
# ...     ...             ...          ...    ...        ...  ...    ...   ...
# 1482   VIC1  31/12/19 21:30      4172.46  58.49      TRADE   31     12  2019
# 1483   VIC1  31/12/19 22:00      4129.96  52.91      TRADE   31     12  2019
# 1484   VIC1  31/12/19 22:30      4083.66  58.66      TRADE   31     12  2019
# 1485   VIC1  31/12/19 23:00      4104.95  54.36      TRADE   31     12  2019
# 1486   VIC1  31/12/19 23:30      4325.88  66.87      TRADE   31     12  2019
#
# [17508 rows x 8 columns]

# %%
grouped_single = Singlecol_2019.groupby(['Month','Day']).agg({'TOTALDEMAND': ['sum']})

print(grouped_single)
# Out:
#           TOTALDEMAND
#                   sum
# Month Day
# 1     1     193379.92
#       2     212941.35
#       3     237579.21
#       4     266576.92
#       5     194525.58
# ...               ...
# 12    27    214512.13
#       28    227043.37
#       29    236587.05
#       30    280820.25
#       31    190820.78
#
# [365 rows x 1 columns]

# %%
### Converting time series format data to csv

grouped_single.to_csv("Timeseries.csv")

# %%
# Grouping the data using "day" column to aggregate the values of totaldemand on a daily basis

jan19 = jan.groupby("Day")["TOTALDEMAND"].sum()
feb19 = feb.groupby("Day")["TOTALDEMAND"].sum()
mar19 = mar.groupby("Day")["TOTALDEMAND"].sum()
apr19 = apr.groupby("Day")["TOTALDEMAND"].sum()
may19 = may.groupby("Day")["TOTALDEMAND"].sum()
jun19 = jun.groupby("Day")["TOTALDEMAND"].sum()
jul19 = jul.groupby("Day")["TOTALDEMAND"].sum()
aug19 = aug.groupby("Day")["TOTALDEMAND"].sum()
sep19 = sep.groupby("Day")["TOTALDEMAND"].sum()
oct19 = oct.groupby("Day")["TOTALDEMAND"].sum()
nov19 = nov.groupby("Day")["TOTALDEMAND"].sum()
dec19 = dec.groupby("Day")["TOTALDEMAND"].sum()

# %%
# Converting the values to dataframe

Year_19 = pd.DataFrame({"January":jan19, 
               "February":feb19,
              "March":mar19, 
               "April":apr19,
                "May":may19,
              "June":jun19, 
               "July":jul19,
              "August":aug19, 
               "September":sep19,
              "October":oct19, 
               "November":nov19,
              "December":dec19}
              )

# %%
Year_19 = Year_19.reset_index()

# %%
Year_19
# Out:
#     Day    January   February      March      April        May       June  \
# 0     1  193379.92  204617.72  321764.54  229249.62  218454.85  236002.00
# 1     2  212941.35  249498.13  292530.23  229854.41  225896.80  236173.86
# 2     3  237579.21  266575.17  277195.38  230377.52  221804.37  270875.70
# 3     4  266576.92  238337.92  273057.62  227527.67  207232.29  272298.25
# 4     5  194525.58  239404.09  252147.06  222969.46  209541.41  275689.63
# 5     6  187212.43  280995.63  217447.23  204459.29  243070.97  269943.55
# 6     7  219749.80  283187.09  229039.73  187180.85  232636.87  264006.88
# 7     8  226892.20  234654.99  234562.40  217087.27  237603.68  234487.26
# 8     9  210966.87  191337.54  213709.87  223998.08  244006.67  221338.84
# 9    10  216157.39  189573.44  203988.11  241717.96  247701.72  216266.06
# 10   11  239457.27  228171.29  206438.16  233781.22  226373.47  245521.84
# 11   12  217257.92  215394.41  220173.40  229697.54  220833.76  256255.50
# ...

# %%
Year_19 = Year_19.drop(['Merged'], axis=1)

# %%
Year_19
# Out:
#     Day    January   February      March      April        May       June  \
# 0     1  193379.92  204617.72  321764.54  229249.62  218454.85  236002.00
# 1     2  212941.35  249498.13  292530.23  229854.41  225896.80  236173.86
# 2     3  237579.21  266575.17  277195.38  230377.52  221804.37  270875.70
# 3     4  266576.92  238337.92  273057.62  227527.67  207232.29  272298.25
# 4     5  194525.58  239404.09  252147.06  222969.46  209541.41  275689.63
# 5     6  187212.43  280995.63  217447.23  204459.29  243070.97  269943.55
# 6     7  219749.80  283187.09  229039.73  187180.85  232636.87  264006.88
# 7     8  226892.20  234654.99  234562.40  217087.27  237603.68  234487.26
# 8     9  210966.87  191337.54  213709.87  223998.08  244006.67  221338.84
# 9    10  216157.39  189573.44  203988.11  241717.96  247701.72  216266.06
# 10   11  239457.27  228171.29  206438.16  233781.22  226373.47  245521.84
# 11   12  217257.92  215394.41  220173.40  229697.54  220833.76  256255.50
# ...

# %%
Year_19.to_csv("DailyDemand_2019.csv")

# %%
import matplotlib.pyplot as plt

plt.plot(Year_19['Day'],Year_19['January'])
plt.title('Demand on daily basis for the month of January (2019)')
plt.xlabel('January')
plt.ylabel('Electricity Demand')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
jan19 = jan.groupby('Month').sum()
feb19 = feb.groupby("Month").sum()
mar19 = mar.groupby("Month").sum()
apr19 = apr.groupby("Month").sum()
may19 = may.groupby("Month").sum()
jun19 = jun.groupby("Month").sum()
jul19 = jul.groupby("Month").sum()
aug19 = aug.groupby("Month").sum()
sep19 = sep.groupby("Month").sum()
oct19 = oct.groupby("Month").sum()
nov19 = nov.groupby("Month").sum()
dec19 = dec.groupby("Month").sum()

# %%
Monthly_19 = jan19.append([feb19, mar19, apr19, may19, jun19, jul19, aug19, sep19, oct19, nov19, dec19])

# %%
Monthly_19
# Out:
#        TOTALDEMAND        RRP    Day     Year
# Month
# 1       7547832.97  372365.36  23807  3002253
# 2       6499619.36  149276.90  19487  2711517
# 3       7224855.01  194935.74  23807  3002253
# 4       6513203.24  141645.45  22319  2905341
# 5       7385070.16  136645.23  23807  3002253
# 6       7773578.06  146544.77  22319  2905341
# 7       7990244.74  127749.92  23807  3002253
# 8       7922190.78  156008.90  23807  3002253
# 9       6972096.92  150750.80  22319  2905341
# 10      6873547.59  149770.03  23807  3002253
# 11      6498928.63   97837.31  22319  2905341
# 12      6836607.07   91263.47  23807  3002253

# %%
Monthly_19 = Monthly_19.reset_index()

# %%
Monthly_19
# Out:
#     Month  TOTALDEMAND        RRP    Day     Year
# 0       1   7547832.97  372365.36  23807  3002253
# 1       2   6499619.36  149276.90  19487  2711517
# 2       3   7224855.01  194935.74  23807  3002253
# 3       4   6513203.24  141645.45  22319  2905341
# 4       5   7385070.16  136645.23  23807  3002253
# 5       6   7773578.06  146544.77  22319  2905341
# 6       7   7990244.74  127749.92  23807  3002253
# 7       8   7922190.78  156008.90  23807  3002253
# 8       9   6972096.92  150750.80  22319  2905341
# 9      10   6873547.59  149770.03  23807  3002253
# 10     11   6498928.63   97837.31  22319  2905341
# 11     12   6836607.07   91263.47  23807  3002253

# %%
Monthly_19.to_csv('MonthlyDemand_2019.csv')

# %%
import matplotlib.pyplot as plt

plt.plot(Monthly_19['Month'], Monthly_19['TOTALDEMAND'])
plt.title('Demand on daily basis for the year 2019')
plt.xlabel('Year 2019')
plt.ylabel('Electricity Demand')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %% [markdown]
# ### YEAR 2018

# %%
# Reading the 2018 dataset 

jan = pd.read_csv("DataSet/Jan18.csv")
janlast = jan.tail(1)
jan = jan[:-1]

feb = pd.read_csv("DataSet/Feb18.csv")
feblast = feb.tail(1)
feb = feb[:-1]
feb.append(janlast, ignore_index = True) 


mar = pd.read_csv("DataSet/Mar18.csv")
marlast = mar.tail(1)
mar = mar[:-1]
mar.append(feblast, ignore_index = True) 



apr = pd.read_csv("DataSet/Apr18.csv")
aprlast = apr.tail(1)
apr = apr[:-1]
apr.append(marlast, ignore_index = True) 


may = pd.read_csv("DataSet/May18.csv")
maylast = may.tail(1)
may = may[:-1]
may.append(aprlast, ignore_index = True) 



jun = pd.read_csv("DataSet/Jun18.csv")
junlast = jun.tail(1)
jun = jun[:-1]
jun.append(maylast, ignore_index = True) 



jul = pd.read_csv("DataSet/Jul18.csv")
jullast = jul.tail(1)
jul = jul[:-1]
jul.append(junlast, ignore_index = True) 



aug = pd.read_csv("DataSet/Aug18.csv")
auglast = aug.tail(1)
aug = aug[:-1]
aug.append(jullast, ignore_index = True) 



sep = pd.read_csv("DataSet/Sep18.csv")
seplast = sep.tail(1)
sep = sep[:-1]
sep.append(auglast, ignore_index = True) 


oct = pd.read_csv("DataSet/Oct18.csv")
octlast = oct.tail(1)
oct = oct[:-1]
oct.append(auglast, ignore_index = True) 



nov = pd.read_csv("DataSet/Nov18.csv")
novlast = nov.tail(1)
nov = nov[:-1]
nov.append(seplast, ignore_index = True) 


dec = pd.read_csv("DataSet/Dec18.csv")
declast = dec.tail(1)
dec = dec[:-1]
dec.append(novlast, ignore_index = True)
# Out:
#      REGION  SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE  Day  Month  Year
# 0      VIC1    1/12/18 0:30      4392.65   97.32      TRADE    1     12  2018
# 1      VIC1    1/12/18 1:00      4251.29   99.68      TRADE    1     12  2018
# 2      VIC1    1/12/18 1:30      4114.46   84.25      TRADE    1     12  2018
# 3      VIC1    1/12/18 2:00      3970.15   82.56      TRADE    1     12  2018
# 4      VIC1    1/12/18 2:30      3892.07   80.77      TRADE    1     12  2018
# ...     ...             ...          ...     ...        ...  ...    ...   ...
# 1483   VIC1  31/12/18 22:00      4292.49   79.39      TRADE   31     12  2018
# 1484   VIC1  31/12/18 22:30      4257.85   77.34      TRADE   31     12  2018
# 1485   VIC1  31/12/18 23:00      4247.55   78.95      TRADE   31     12  2018
# 1486   VIC1  31/12/18 23:30      4439.96   75.33      TRADE   31     12  2018
# 1487   VIC1    1/12/18 0:00      4579.83  111.31      TRADE    1     12  2018
#
# [1488 rows x 8 columns]

# %%
frames = [jan,feb,mar,apr,may,jun,jul,aug,sep,oct,nov,dec]

demand18 = pd.concat(frames)

# %%
demand18
# Out:
#      REGION  SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE  Day  Month  Year
# 0      VIC1     1/1/18 0:30      4251.18  92.46      TRADE    1      1  2018
# 1      VIC1     1/1/18 1:00      4092.53  87.62      TRADE    1      1  2018
# 2      VIC1     1/1/18 1:30      3958.95  73.08      TRADE    1      1  2018
# 3      VIC1     1/1/18 2:00      3785.27  70.18      TRADE    1      1  2018
# 4      VIC1     1/1/18 2:30      3673.72  67.43      TRADE    1      1  2018
# ...     ...             ...          ...    ...        ...  ...    ...   ...
# 1482   VIC1  31/12/18 21:30      4361.43  92.39      TRADE   31     12  2018
# 1483   VIC1  31/12/18 22:00      4292.49  79.39      TRADE   31     12  2018
# 1484   VIC1  31/12/18 22:30      4257.85  77.34      TRADE   31     12  2018
# 1485   VIC1  31/12/18 23:00      4247.55  78.95      TRADE   31     12  2018
# 1486   VIC1  31/12/18 23:30      4439.96  75.33      TRADE   31     12  2018
#
# [17508 rows x 8 columns]

# %%
demand18['SETTLEMENTDATE']= pd.to_datetime(demand18['SETTLEMENTDATE'])

# %%
demand18 = demand18.groupby(['Month','Day'])['TOTALDEMAND'].sum()

# %%
demand18 = demand18.reset_index()

# %%
demand18
# Out:
#      Month  Day  TOTALDEMAND
# 0        1    1    187474.30
# 1        1    2    210555.70
# 2        1    3    212747.65
# 3        1    4    226675.37
# 4        1    5    246495.47
# ..     ...  ...          ...
# 360     12   27    259498.28
# 361     12   28    267662.75
# 362     12   29    216580.22
# 363     12   30    199227.73
# 364     12   31    206763.83
#
# [365 rows x 3 columns]

# %%
demand18.to_csv("Timeseries_2018.csv")

# %%
# Grouping the data using "day" column to aggregate the values of totaldemand on a daily basis

jan18 = jan.groupby("Day")["TOTALDEMAND"].sum()
feb18 = feb.groupby("Day")["TOTALDEMAND"].sum()
mar18 = mar.groupby("Day")["TOTALDEMAND"].sum()
apr18 = apr.groupby("Day")["TOTALDEMAND"].sum()
may18 = may.groupby("Day")["TOTALDEMAND"].sum()
jun18 = jun.groupby("Day")["TOTALDEMAND"].sum()
jul18 = jul.groupby("Day")["TOTALDEMAND"].sum()
aug18 = aug.groupby("Day")["TOTALDEMAND"].sum()
sep18 = sep.groupby("Day")["TOTALDEMAND"].sum()
oct18 = oct.groupby("Day")["TOTALDEMAND"].sum()
nov18 = nov.groupby("Day")["TOTALDEMAND"].sum()
dec18 = dec.groupby("Day")["TOTALDEMAND"].sum()

# %%
# Converting the values to dataframe

Year_18 = pd.DataFrame({"January":jan18, 
               "February":feb18,
              "March":mar18, 
               "April":apr18,
                "May":may18,
              "June":jun18, 
               "July":jul18,
              "August":aug18, 
               "September":sep18,
              "October":oct18, 
               "November":nov18,
              "December":dec18}
              )

# %%
Year_18 = Year_18.reset_index()

# %%
Year_18
# Out:
#     Day    January   February      March      April        May       June  \
# 0     1  187474.30  215482.81  230168.04  193264.36  240180.69  266291.20
# 1     2  210555.70  225892.68  239920.66  196516.50  237433.19  246452.15
# 2     3  212747.65  209894.65  222192.61  226763.06  234715.67  242355.17
# 3     4  226675.37  212131.87  202668.40  231949.22  233740.92  270770.82
# 4     5  246495.47  252931.92  225054.57  235103.39  213785.99  265950.26
# 5     6  267411.69  275079.45  227701.62  231958.14  211680.78  264076.85
# 6     7  214285.63  318614.63  245435.00  211876.95  236509.11  257155.26
# 7     8  237664.14  298946.02  257465.18  201142.33  245753.73  259820.03
# 8     9  222722.10  274203.74  255610.97  237405.85  245442.92  240464.39
# 9    10  233060.08  236227.60  240797.77  244846.02  257037.01  234075.73
# 10   11  279215.81  200880.58  208972.36  243889.99  266934.74  226841.97
# 11   12  264045.74  232418.26  195084.62  239753.26  222547.51  254522.59
# ...

# %%
Year_18.to_csv("DailyDemand_2018.csv")

# %%
import matplotlib.pyplot as plt

plt.plot(Year_18['Day'],Year_18['January'])
plt.title('Demand on daily basis for the month of January (2018)')
plt.xlabel('January')
plt.ylabel('Electricity Demand')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
### GroupBy months for the year 2018

jan18 = jan.groupby('Month').sum()
feb18 = feb.groupby("Month").sum()
mar18 = mar.groupby("Month").sum()
apr18 = apr.groupby("Month").sum()
may18 = may.groupby("Month").sum()
jun18 = jun.groupby("Month").sum()
jul18 = jul.groupby("Month").sum()
aug18 = aug.groupby("Month").sum()
sep18 = sep.groupby("Month").sum()
oct18 = oct.groupby("Month").sum()
nov18 = nov.groupby("Month").sum()
dec18 = dec.groupby("Month").sum()

# %%
# Converting the values to dataframe

Monthly_18 = jan18.append([feb18, mar18, apr18, may18, jun18, jul18, aug18, sep18, oct18, nov18, dec18])

# %%
Monthly_18 = Monthly_18.reset_index()

# %%
Monthly_18.to_csv('MonthlyDemand_2018.csv')

# %%
import matplotlib.pyplot as plt

plt.plot(Monthly_18['Month'], Monthly_18['TOTALDEMAND'])
plt.title('Demand on monthly basis for the year 2018')
plt.xlabel('Year 2018')
plt.ylabel('Electricity Demand')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(Monthly_19['Month'], Monthly_19['TOTALDEMAND'])
plt.title('Demand on daily basis for the year 2019')
plt.xlabel('Year 2019')
plt.ylabel('Electricity Demand')
plt.show()

# %%
# Reading the 2020 dataset 

jan = pd.read_csv("DataSet/Jan.csv")
janlast = jan.tail(1)
jan = jan[:-1]

feb = pd.read_csv("DataSet/Feb.csv")
feblast = feb.tail(1)
feb = feb[:-1]
feb.append(janlast, ignore_index = True) 


mar = pd.read_csv("DataSet/Mar.csv")
marlast = mar.tail(1)
mar = mar[:-1]
mar.append(feblast, ignore_index = True) 



apr = pd.read_csv("DataSet/Apr.csv")
aprlast = apr.tail(1)
apr = apr[:-1]
apr.append(marlast, ignore_index = True) 


may = pd.read_csv("DataSet/May.csv")
maylast = may.tail(1)
may = may[:-1]
may.append(aprlast, ignore_index = True) 



jun = pd.read_csv("DataSet/Jun.csv")
junlast = jun.tail(1)
jun = jun[:-1]
jun.append(maylast, ignore_index = True) 



jul = pd.read_csv("DataSet/Jul.csv")
jullast = jul.tail(1)
jul = jul[:-1]
jul.append(junlast, ignore_index = True) 



aug = pd.read_csv("DataSet/Aug.csv")
auglast = aug.tail(1)
aug = aug[:-1]
aug.append(jullast, ignore_index = True) 



sep = pd.read_csv("DataSet/Sept.csv")
seplast = sep.tail(1)
sep = sep[:-1]
sep.append(auglast, ignore_index = True)
# Out:
#      REGION SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE  Day  Month  Year
# 0      VIC1    1/9/20 0:30      5074.43  57.13      TRADE    1      9  2020
# 1      VIC1    1/9/20 1:00      4981.56  52.82      TRADE    1      9  2020
# 2      VIC1    1/9/20 1:30      4856.36  50.82      TRADE    1      9  2020
# 3      VIC1    1/9/20 2:00      4682.04  50.20      TRADE    1      9  2020
# 4      VIC1    1/9/20 2:30      4537.91  43.81      TRADE    1      9  2020
# ...     ...            ...          ...    ...        ...  ...    ...   ...
# 1435   VIC1  30/9/20 22:00      4893.41  34.92      TRADE   30      9  2020
# 1436   VIC1  30/9/20 22:30      4711.86  39.62      TRADE   30      9  2020
# 1437   VIC1  30/9/20 23:00      4626.24  36.67      TRADE   30      9  2020
# 1438   VIC1  30/9/20 23:30      4832.32  38.26      TRADE   30      9  2020
# 1439   VIC1    1/9/20 0:00      5313.03  59.03      TRADE    1      9  2020
#
# [1440 rows x 8 columns]

# %%
frames = [jan,feb,mar,apr,may,jun,jul,aug,sep]

demand20 = pd.concat(frames)

# %%
demand20
# Out:
#      REGION SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE  Day  Month  Year
# 0      VIC1    1/1/20 0:30      4185.32  64.76      TRADE    1      1  2020
# 1      VIC1    1/1/20 1:00      4057.68  63.36      TRADE    1      1  2020
# 2      VIC1    1/1/20 1:30      3954.85  65.21      TRADE    1      1  2020
# 3      VIC1    1/1/20 2:00      3792.25  64.45      TRADE    1      1  2020
# 4      VIC1    1/1/20 2:30      3689.33  63.23      TRADE    1      1  2020
# ...     ...            ...          ...    ...        ...  ...    ...   ...
# 1434   VIC1  30/9/20 21:30      5122.16  36.94      TRADE   30      9  2020
# 1435   VIC1  30/9/20 22:00      4893.41  34.92      TRADE   30      9  2020
# 1436   VIC1  30/9/20 22:30      4711.86  39.62      TRADE   30      9  2020
# 1437   VIC1  30/9/20 23:00      4626.24  36.67      TRADE   30      9  2020
# 1438   VIC1  30/9/20 23:30      4832.32  38.26      TRADE   30      9  2020
#
# [13143 rows x 8 columns]

# %%
## Convert to datetime
demand20['SETTLEMENTDATE']= pd.to_datetime(demand20['SETTLEMENTDATE'])

# %%
demand20
# Out:
#      REGION      SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE  Day  Month  \
# 0      VIC1 2020-01-01 00:30:00      4185.32  64.76      TRADE    1      1
# 1      VIC1 2020-01-01 01:00:00      4057.68  63.36      TRADE    1      1
# 2      VIC1 2020-01-01 01:30:00      3954.85  65.21      TRADE    1      1
# 3      VIC1 2020-01-01 02:00:00      3792.25  64.45      TRADE    1      1
# 4      VIC1 2020-01-01 02:30:00      3689.33  63.23      TRADE    1      1
# ...     ...                 ...          ...    ...        ...  ...    ...
# 1434   VIC1 2020-09-30 21:30:00      5122.16  36.94      TRADE   30      9
# 1435   VIC1 2020-09-30 22:00:00      4893.41  34.92      TRADE   30      9
# 1436   VIC1 2020-09-30 22:30:00      4711.86  39.62      TRADE   30      9
# 1437   VIC1 2020-09-30 23:00:00      4626.24  36.67      TRADE   30      9
# 1438   VIC1 2020-09-30 23:30:00      4832.32  38.26      TRADE   30      9
#
#       Year
# 0     2020
# 1     2020
# 2     2020
# 3     2020
# ...

# %%
demand20 = demand20.groupby(['Month','Day'])['TOTALDEMAND'].sum()

# %%
demand20
# Out:
# Month  Day
# 1      1      173783.44
#        2      205976.37
#        3      237844.43
#        4      204491.22
#        5      191342.40
#                 ...
# 9      26     213389.93
#        27     203406.98
#        28     229302.28
#        29     224152.92
#        30     227240.42
# Name: TOTALDEMAND, Length: 274, dtype: float64

# %%
demand20 = demand20.reset_index()

# %%
demand20.columns
# Out:
# Index(['Month', 'Day', 'TOTALDEMAND'], dtype='object')

# %%
demand20.to_csv('demand20.csv')

# %%
# Grouping the data using "day" column to aggregate the values of totaldemand on a daily basis

jan20 = jan.groupby("Day")["TOTALDEMAND"].sum()
feb20 = feb.groupby("Day")["TOTALDEMAND"].sum()
mar20 = mar.groupby("Day")["TOTALDEMAND"].sum()
apr20 = apr.groupby("Day")["TOTALDEMAND"].sum()
may20 = may.groupby("Day")["TOTALDEMAND"].sum()
jun20 = jun.groupby("Day")["TOTALDEMAND"].sum()
jul20 = jul.groupby("Day")["TOTALDEMAND"].sum()
aug20 = aug.groupby("Day")["TOTALDEMAND"].sum()
sep20 = sep.groupby("Day")["TOTALDEMAND"].sum()

# %%
# Converting the values to dataframe

Year_20 = pd.DataFrame({"January":jan20, 
               "February":feb20,
              "March":mar20, 
               "April":apr20,
                "May":may20,
              "June":jun20, 
               "July":jul20,
              "August":aug20, 
               "September":sep20}
              )

# %%
Year_20 = Year_20.reset_index()

# %%
Year_20
# Out:
#     Day    January   February      March      April        May       June  \
# 0     1  173783.44  257595.21  198356.22  217339.47  249641.63  259602.25
# 1     2  205976.37  195218.12  212719.91  232605.33  223331.45  265420.72
# 2     3  237844.43  210009.82  217492.74  208589.14  219338.71  261603.65
# 3     4  204491.22  214068.13  235011.25  203708.31  253784.52  266644.05
# 4     5  191342.40  217976.88  239469.27  210196.05  237678.19  274736.93
# 5     6  220507.18  241138.92  222644.65  236149.13  226428.54  252855.84
# 6     7  218673.12  241469.70  193701.56  236808.91  219285.51  239048.82
# 7     8  220077.25  215728.89  185106.58  216808.02  215828.11  249585.95
# 8     9  254731.18  207714.22  189283.40  217175.04  215572.51  283142.59
# 9    10  245067.76  245950.92  224285.08  189662.46  215110.38  275591.59
# 10   11  183773.21  254221.16  237660.28  184194.14  245101.89  282888.89
# 11   12  183595.19  249237.13  240545.55  203520.18  241535.59  269369.17
# ...

# %%
Year_20.to_csv("DailyDemand_2020.csv")

# %%
import matplotlib.pyplot as plt

plt.plot(Year_20['Day'],Year_20['January'])
plt.title('Demand on daily basis for the month of January (2020)')
plt.xlabel('January')
plt.ylabel('Electricity Demand')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
### GroupBy months for the year 2018

jan20 = jan.groupby('Month').sum()
feb20 = feb.groupby("Month").sum()
mar20 = mar.groupby("Month").sum()
apr20 = apr.groupby("Month").sum()
may20 = may.groupby("Month").sum()
jun20 = jun.groupby("Month").sum()
jul20 = jul.groupby("Month").sum()
aug20 = aug.groupby("Month").sum()
sep20 = sep.groupby("Month").sum()

# %%
Monthly_20 = jan20.append([feb20, mar20, apr20, may20, jun20, jul20, aug20, sep20])

# %%
Monthly_20 = Monthly_20.reset_index()

# %%
Monthly_20.to_csv('MonthlyDemand_2020.csv')

# %%
import matplotlib.pyplot as plt

plt.plot(Monthly_20['Month'], Monthly_20['TOTALDEMAND'])
plt.title('Demand on monthly basis for the year 2020')
plt.xlabel('Year 2020')
plt.ylabel('Electricity Demand')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
import matplotlib.pyplot as plt

plt.plot(Monthly_19['Month'], Monthly_19['TOTALDEMAND'])
plt.title('Demand on daily basis for the year 2019')
plt.xlabel('Year 2019')
plt.ylabel('Electricity Demand')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
vic_weather = pd.read_csv("Victoria_Weather.csv")

# %%
vic_weather.head()
# Out:
#       date  max_temperature  avg_hourly_temperature  avg_temperature  \
# 0  11/1/18              6.4                    4.01             4.50
# 1  12/1/18              7.1                    4.99             5.09
# 2  13/1/18              7.4                    6.32             5.65
# 3  14/1/18             10.5                    5.74             7.20
# 4  15/1/18              9.2                    6.13             5.60
#
#    min_temperature  max_humidex  min_windchill  max_relative_humidity  \
# 0              2.6          NaN            NaN                   98.0
# 1              3.1          NaN            NaN                   99.0
# 2              3.9          NaN            NaN                  100.0
# 3              3.9          NaN            NaN                  100.0
# 4              2.0          NaN            NaN                  100.0
#
#    avg_hourly_relative_humidity  avg_relative_humidity  ...  \
# 0                          95.9                   94.5  ...
# ...

# %%
vic_weather20 = vic_weather[vic_weather['Year'] == 2020]
vic_weather20

# %%
vic_weather18 = vic_weather[vic_weather['Year'] == 2018]
vic_weather18
# Out:
#          date  max_temperature  avg_hourly_temperature  avg_temperature  \
# 0     11/1/18              6.4                    4.01             4.50
# 1     12/1/18              7.1                    4.99             5.09
# 2     13/1/18              7.4                    6.32             5.65
# 3     14/1/18             10.5                    5.74             7.20
# 4     15/1/18              9.2                    6.13             5.60
# ..        ...              ...                     ...              ...
# 350  27/12/18              6.3                    3.72             3.05
# 351  28/12/18              7.2                    5.69             5.75
# 352  29/12/18             11.9                    8.99             8.25
# 353  30/12/18              8.8                    4.89             4.30
# 354  31/12/18              5.9                    2.52             2.35
#
#      min_temperature  max_humidex  min_windchill  max_relative_humidity  \
# ...

# %%
vic_weather19 = vic_weather[vic_weather['Year'] == 2019]
vic_weather19
# Out:
#          date  max_temperature  avg_hourly_temperature  avg_temperature  \
# 355    1/1/19              5.5                    3.37             3.30
# 356    2/1/19              6.6                    4.18             3.84
# 357    3/1/19              9.1                    8.07             7.75
# 358    4/1/19             11.4                    8.55             8.85
# 359    5/1/19              8.3                    6.45             6.35
# ..        ...              ...                     ...              ...
# 715  27/12/19              5.8                    3.39             3.00
# 716  28/12/19              6.9                    5.79             5.55
# 717  29/12/19              8.9                    6.90             7.15
# 718  30/12/19              9.1                    7.30             7.30
# 719  31/12/19             13.1                    9.25            10.25
#
#      min_temperature  max_humidex  min_windchill  max_relative_humidity  \
# ...

# %%
vic_weather20
# Out:
#         date  max_temperature  avg_hourly_temperature  avg_temperature  \
# 720   1/1/20             12.9                    9.59             9.19
# 721   2/1/20              6.0                    4.33             3.45
# 722   3/1/20             10.9                    8.98             8.40
# 723   4/1/20              8.2                    5.75             5.65
# 724   5/1/20              8.3                    6.32             6.55
# ..       ...              ...                     ...              ...
# 995  2/10/20             21.5                   15.30            16.20
# 996  3/10/20             14.6                   11.80            12.39
# 997  4/10/20             15.8                   12.64            12.95
# 998  5/10/20             18.0                   13.32            14.40
# 999  6/10/20             17.6                   13.30            14.05
#
#      min_temperature  max_humidex  min_windchill  max_relative_humidity  \
# ...

# %%
for i in vic_weather.columns:
    print(i)
# Out:
# date
# max_temperature
# avg_hourly_temperature
# avg_temperature
# min_temperature
# max_humidex
# min_windchill
# max_relative_humidity
# avg_hourly_relative_humidity
# avg_relative_humidity
# min_relative_humidity
# max_dew_point
# avg_hourly_dew_point
# avg_dew_point
# min_dew_point
# max_wind_speed
# avg_hourly_wind_speed
# avg_wind_speed
# min_wind_speed
# max_wind_gust
# wind_gust_dir_10s
# max_pressure_sea
# avg_hourly_pressure_sea
# avg_pressure_sea
# min_pressure_sea
# max_pressure_station
# avg_hourly_pressure_station
# avg_pressure_station
# min_pressure_station
# max_visibility
# avg_hourly_visibility
# avg_visibility
# min_visibility
# max_health_index
# avg_hourly_health_index
# avg_health_index
# min_health_index
# heatdegdays
# cooldegdays
# growdegdays_5
# growdegdays_7
# growdegdays_10
# precipitation
# rain
# snow
# snow_on_ground
# sunrise
# sunset
# daylight
# sunrise_f
# sunset_f
# min_uv_forecast
# max_uv_forecast
# min_high_temperature_forecast
# ...

# %%
##### Reading the whole year demand data

ts_data = pd.read_csv("Timeseries_2019.csv")

# %%
ts_data
# Out:
#      Month  Day  TotalDEMAND      date  max_temperature  \
# 0        1    1    193379.92    1/1/19              5.5
# 1        1    2    212941.35    2/1/19              6.6
# 2        1    3    237579.21    3/1/19              9.1
# 3        1    4    266576.92    4/1/19             11.4
# 4        1    5    194525.58    5/1/19              8.3
# ..     ...  ...          ...       ...              ...
# 360     12   27    214512.13  27/12/19              5.8
# 361     12   28    227043.37  28/12/19              6.9
# 362     12   29    236587.05  29/12/19              8.9
# 363     12   30    280820.25  30/12/19              9.1
# 364     12   31    190820.78  31/12/19             13.1
#
#      avg_hourly_temperature  avg_temperature  min_temperature  max_humidex  \
# 0                      3.37             3.30              1.1          NaN
# 1                      4.18             3.84              1.1          NaN
# ...

# %%
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

ts_data['TotalDEMAND'].plot(linewidth=0.5);
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
ts_data.columns
# Out:
# Index(['Month', 'Day', 'TotalDEMAND', 'date', 'max_temperature',
#        'avg_hourly_temperature', 'avg_temperature', 'min_temperature',
#        'max_humidex', 'min_windchill', 'max_relative_humidity',
#        'avg_hourly_relative_humidity', 'avg_relative_humidity',
#        'min_relative_humidity', 'max_dew_point', 'avg_hourly_dew_point',
#        'avg_dew_point', 'min_dew_point', 'max_wind_speed',
#        'avg_hourly_wind_speed', 'avg_wind_speed', 'min_wind_speed',
#        'max_wind_gust', 'wind_gust_dir_10s', 'max_pressure_sea',
#        'avg_hourly_pressure_sea', 'avg_pressure_sea', 'min_pressure_sea',
#        'max_pressure_station', 'avg_hourly_pressure_station',
#        'avg_pressure_station', 'min_pressure_station', 'max_visibility',
#        'avg_hourly_visibility', 'avg_visibility', 'min_visibility',
#        'max_health_index', 'avg_hourly_health_index', 'avg_health_index',
#        'min_health_index', 'heatdegdays', 'cooldegdays', 'growdegdays_5',
# ...

# %%
ts_data['cooldegdays'].unique()
# Out:
# array([0. , 0.1, 1.5, 3.8, 2. , 1.1, 2.9, 0.2, 0.8, 1.8, 0.9, 4. , 1.6,
#        0.4, 1.9, 2.2, 0.5, 2.1, 1. , 0.6, nan])

# %%
ts_data['heatdegdays'].unique()
# Out:
# array([14.7, 14.2, 10.2,  9.2, 11.7, 13.6, 15.6, 11.6,  9.1, 11.2, 12.1,
#        12.2, 13.8, 14.9, 14.3, 11.8,  9.6, 11.4, 13.9, 14.6, 13.3, 12. ,
#        12.7, 12.4, 13.4, 12.8, 14.1, 15.1, 10.7, 18.1, 20.7, 20.6, 19.4,
#        18.9, 18.4, 19.2, 20.8, 20.1, 17.8, 20.5, 15.2, 14.4, 16.2, 16.6,
#        15.8, 16.3, 16. , 13.7, 16.1, 15.4, 15.5, 16.5, 16.9, 15.9, 15.7,
#        10.3,  9.5,  9. ,  7.2,  7.5,  5.6,  8.7,  8.3, 10.1, 10.4,  9.3,
#         7.7,  8.1,  6.5,  6.1,  6.2,  8.8,  7.8,  8.4,  9.7, 10.9,  6.7,
#         7. ,  7.3,  8.6,  6.3,  6. ,  9.9,  5.8,  6.8,  4.9,  4.8,  3.9,
#         0.4,  0.2,  3.1,  3. ,  3.5,  4.1,  1.5,  5. ,  4.2,  2.1,  5.3,
#         2.3,  4.4,  2.2,  0. ,  2.8,  3.6,  6.4,  1.6,  2.5,  2. ,  0.1,
#         3.8,  0.8,  2.6,  1.1,  0.9,  1.9,  2.9,  1.2,  0.5,  1.8,  0.6,
#         1.4,  1.3,  1. ,  2.7,  5.1,  4.7,  5.2,  3.4,  5.5,  3.3,  2.4,
#         nan,  3.2,  5.9,  4.6,  9.8, 12.6, 10.8,  8.2,  9.4, 11.3, 12.3,
# ...

# %%
ts_data['heatdegdays'].plot()

# %%
ts_data['cooldegdays'].plot()

# %%
#plt.plot( 'Day', 'January', data=Year_18, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'Day', 'January', data=Year_19, marker='', color='olive', linewidth=2)
plt.plot( 'Day', 'January', data=Year_20, marker='', color='Green', linewidth=2, linestyle='dashed', label="toto")
plt.legend()

# %%
Year_19.columns
# Out:
# Index(['Day', 'January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object')

# %%
#plt.plot( 'Day', 'January', data=Year_18, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'Day', 'April', data=Year_19, marker='', color='olive', linewidth=2)
plt.plot( 'Day', 'April', data=Year_20, marker='', color='Green', linewidth=2, linestyle='dashed', label="toto")
plt.legend()

# %%
#plt.plot( 'Day', 'January', data=Year_18, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'Day', 'May', data=Year_19, marker='', color='olive', linewidth=2)
plt.plot( 'Day', 'May', data=Year_20, marker='', color='Green', linewidth=2, linestyle='dashed', label="toto")
plt.legend()

# %%
#plt.plot( 'Day', 'January', data=Year_18, marker='o', markerfacecolor='blue', markersize=12, color='skyblue', linewidth=4)
plt.plot( 'Day', 'July', data=Year_19, marker='', color='olive', linewidth=2, label="2019")
plt.plot( 'Day', 'July', data=Year_20, marker='', color='Green', linewidth=2, linestyle='dashed', label="2020")
plt.legend()

# %%
Year_18.columns
# Out:
# Index(['Day', 'January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype='object')

# %% [markdown]
# ###### JANUARY TIMEWISE EXPLORATION

# %%
apr19 = aug

# %%
apr20 = aug

# %%
apr19.head()
# Out:
#   REGION SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE  Day  Month  Year
# 0   VIC1    1/8/19 0:30      5324.45  101.48      TRADE    1      8  2019
# 1   VIC1    1/8/19 1:00      5140.63  100.39      TRADE    1      8  2019
# 2   VIC1    1/8/19 1:30      4939.77   87.16      TRADE    1      8  2019
# 3   VIC1    1/8/19 2:00      4720.44   78.69      TRADE    1      8  2019
# 4   VIC1    1/8/19 2:30      4580.39   83.38      TRADE    1      8  2019

# %%
apr20.head()
# Out:
#   REGION SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE  Day  Month  Year
# 0   VIC1    1/8/20 0:30      5075.11  53.39      TRADE    1      8  2020
# 1   VIC1    1/8/20 1:00      4848.77  45.41      TRADE    1      8  2020
# 2   VIC1    1/8/20 1:30      4746.14  52.34      TRADE    1      8  2020
# 3   VIC1    1/8/20 2:00      4520.01  45.42      TRADE    1      8  2020
# 4   VIC1    1/8/20 2:30      4383.36  46.94      TRADE    1      8  2020

# %%
apr19['SETTLEMENTDATE']= pd.to_datetime(apr19['SETTLEMENTDATE'])

# %%
apr19['new_date'] = [d.date() for d in apr19['SETTLEMENTDATE']]
apr19['new_time'] = [d.time() for d in apr19['SETTLEMENTDATE']]

# %%
apr19
# Out:
#      REGION      SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE  Day  Month  \
# 0      VIC1 2019-01-08 00:30:00      5324.45  101.48      TRADE    1      8
# 1      VIC1 2019-01-08 01:00:00      5140.63  100.39      TRADE    1      8
# 2      VIC1 2019-01-08 01:30:00      4939.77   87.16      TRADE    1      8
# 3      VIC1 2019-01-08 02:00:00      4720.44   78.69      TRADE    1      8
# 4      VIC1 2019-01-08 02:30:00      4580.39   83.38      TRADE    1      8
# ...     ...                 ...          ...     ...        ...  ...    ...
# 1482   VIC1 2019-08-31 21:30:00      5045.00  106.96      TRADE   31      8
# 1483   VIC1 2019-08-31 22:00:00      4911.24  108.75      TRADE   31      8
# 1484   VIC1 2019-08-31 22:30:00      4792.16  113.73      TRADE   31      8
# 1485   VIC1 2019-08-31 23:00:00      4736.72  103.11      TRADE   31      8
# 1486   VIC1 2019-08-31 23:30:00      4900.60  117.88      TRADE   31      8
#
#       Year    new_date  new_time
# ...

# %%
apr19 = apr19[apr19['Day'] == 5]
apr19
# Out:
#     REGION      SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE  Day  Month  \
# 191   VIC1 2019-05-08 00:00:00      5066.61  120.85      TRADE    5      8
# 192   VIC1 2019-05-08 00:30:00      4870.86  105.79      TRADE    5      8
# 193   VIC1 2019-05-08 01:00:00      4713.32   93.30      TRADE    5      8
# 194   VIC1 2019-05-08 01:30:00      4508.10   85.99      TRADE    5      8
# 195   VIC1 2019-05-08 02:00:00      4336.08   87.03      TRADE    5      8
# 196   VIC1 2019-05-08 02:30:00      4198.61   68.99      TRADE    5      8
# 197   VIC1 2019-05-08 03:00:00      4125.95   59.05      TRADE    5      8
# 198   VIC1 2019-05-08 03:30:00      4075.85   58.48      TRADE    5      8
# 199   VIC1 2019-05-08 04:00:00      4034.63   57.51      TRADE    5      8
# 200   VIC1 2019-05-08 04:30:00      4034.48   56.63      TRADE    5      8
# 201   VIC1 2019-05-08 05:00:00      4103.05   56.90      TRADE    5      8
# ...

# %%
apr20['SETTLEMENTDATE']= pd.to_datetime(apr20['SETTLEMENTDATE'])

# %%
apr20['new_date'] = [d.date() for d in apr20['SETTLEMENTDATE']]
apr20['new_time'] = [d.time() for d in apr20['SETTLEMENTDATE']]

# %%
apr20 = apr20[apr20['Day'] == 5]
apr20
# Out:
#     REGION      SETTLEMENTDATE  TOTALDEMAND     RRP PERIODTYPE  Day  Month  \
# 191   VIC1 2020-05-08 00:00:00      5430.13   47.59      TRADE    5      8
# 192   VIC1 2020-05-08 00:30:00      5247.13   41.62      TRADE    5      8
# 193   VIC1 2020-05-08 01:00:00      5065.40   38.75      TRADE    5      8
# 194   VIC1 2020-05-08 01:30:00      4913.92   35.06      TRADE    5      8
# 195   VIC1 2020-05-08 02:00:00      4745.25   32.24      TRADE    5      8
# 196   VIC1 2020-05-08 02:30:00      4565.80   28.52      TRADE    5      8
# 197   VIC1 2020-05-08 03:00:00      4424.32   17.86      TRADE    5      8
# 198   VIC1 2020-05-08 03:30:00      4342.81   11.99      TRADE    5      8
# 199   VIC1 2020-05-08 04:00:00      4303.92    8.42      TRADE    5      8
# 200   VIC1 2020-05-08 04:30:00      4325.34   15.12      TRADE    5      8
# 201   VIC1 2020-05-08 05:00:00      4320.09   22.04      TRADE    5      8
# ...

# %%
apr19["new_time"] = apr19["new_time"].astype(str)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
apr20["new_time"] = apr20["new_time"].astype(str)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(20,10))
plt.plot( 'new_time', 'TOTALDEMAND', data=apr19, marker='', color='green', linewidth=2, label="August 2019")
plt.plot( 'new_time', 'TOTALDEMAND', data=apr20, marker='', color='orange', linewidth=2, label="August 2020")
plt.legend()

# %%
apr19 = apr19[0:20]
apr20 = apr20[0:20]

# %% [markdown]
# ## FootFall Analytics

# %%
import pandas as pd

footfall = pd.read_csv("Pedestrian_Counting_System___2009_to_Present__counts_per_hour_.csv")

# %%
footfall['Year'].unique()
# Out:
# array([2019, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018,
#        2020])

# %%
 footfall_18 = footfall[footfall['Year']==2018]

# %%
footfall_19 = footfall[footfall['Year']==2019]

# %%
footfall_20 = footfall[footfall['Year']==2020]

# %%
footfall_18['Year'].unique()
# Out:
# array([2018])

# %%
footfall_19['Year'].unique()
# Out:
# array([2019])

# %%
footfall_20['Year'].unique()
# Out:
# array([2020])

# %%
frames = [footfall_18, footfall_19, footfall_20]

footfall = pd.concat(frames)

# %%
footfall
# Out:
#               ID               Date_Time  Year      Month  Mdate        Day  \
# 2118544  2212931  04/27/2018 11:00:00 PM  2018      April     27     Friday
# 2118545  2212932  04/27/2018 11:00:00 PM  2018      April     27     Friday
# 2118546  2212933  04/27/2018 11:00:00 PM  2018      April     27     Friday
# 2118547  2212934  04/27/2018 11:00:00 PM  2018      April     27     Friday
# 2118548  2212935  04/27/2018 11:00:00 PM  2018      April     27     Friday
# ...          ...                     ...   ...        ...    ...        ...
# 3347333  3347334  09/30/2020 11:00:00 PM  2020  September     30  Wednesday
# 3347334  3347335  09/30/2020 11:00:00 PM  2020  September     30  Wednesday
# 3347335  3347336  09/30/2020 11:00:00 PM  2020  September     30  Wednesday
# 3347336  3347337  09/30/2020 11:00:00 PM  2020  September     30  Wednesday
# 3347337  3347338  09/30/2020 11:00:00 PM  2020  September     30  Wednesday
#
# ...

# %%
footfall['Date_Time']
# Out:
# 2118544    04/27/2018 11:00:00 PM
# 2118545    04/27/2018 11:00:00 PM
# 2118546    04/27/2018 11:00:00 PM
# 2118547    04/27/2018 11:00:00 PM
# 2118548    04/27/2018 11:00:00 PM
#                     ...
# 3347333    09/30/2020 11:00:00 PM
# 3347334    09/30/2020 11:00:00 PM
# 3347335    09/30/2020 11:00:00 PM
# 3347336    09/30/2020 11:00:00 PM
# 3347337    09/30/2020 11:00:00 PM
# Name: Date_Time, Length: 1267401, dtype: object

# %%
## Convert to datetime
footfall['Date_Time']= pd.to_datetime(footfall['Date_Time'])

# %%
footfall['Date'] = [d.date() for d in footfall['Date_Time']]
footfall['Time'] = [d.time() for d in footfall['Date_Time']]

# %%
footfall
# Out:
#               ID           Date_Time  Year      Month  Mdate        Day  \
# 2118544  2212931 2018-04-27 23:00:00  2018      April     27     Friday
# 2118545  2212932 2018-04-27 23:00:00  2018      April     27     Friday
# 2118546  2212933 2018-04-27 23:00:00  2018      April     27     Friday
# 2118547  2212934 2018-04-27 23:00:00  2018      April     27     Friday
# 2118548  2212935 2018-04-27 23:00:00  2018      April     27     Friday
# ...          ...                 ...   ...        ...    ...        ...
# 3347333  3347334 2020-09-30 23:00:00  2020  September     30  Wednesday
# 3347334  3347335 2020-09-30 23:00:00  2020  September     30  Wednesday
# 3347335  3347336 2020-09-30 23:00:00  2020  September     30  Wednesday
# 3347336  3347337 2020-09-30 23:00:00  2020  September     30  Wednesday
# 3347337  3347338 2020-09-30 23:00:00  2020  September     30  Wednesday
#
#              Time  Sensor_ID                          Sensor_Name  \
# ...

# %%
foot = footfall.groupby(['Date','Time','Day'])['Hourly_Counts'].sum()

# %%
foot
# Out:
# Date        Time      Day
# 2018-01-01  00:00:00  Monday       59309
#             01:00:00  Monday       50937
#             02:00:00  Monday       29919
#             03:00:00  Monday       17645
#             04:00:00  Monday        9583
#                                    ...
# 2020-09-30  19:00:00  Wednesday     5676
#             20:00:00  Wednesday     3379
#             21:00:00  Wednesday     2313
#             22:00:00  Wednesday     1745
#             23:00:00  Wednesday     1046
# Name: Hourly_Counts, Length: 24096, dtype: int64

# %%
foot = pd.DataFrame(foot)

# %%
type(foot)
# Out:
# pandas.core.frame.DataFrame

# %%
foot = foot.reset_index()

# %%
foot.columns
# Out:
# Index(['Date', 'Time', 'Day', 'Hourly_Counts'], dtype='object')

# %%
footMedian = foot.groupby(['Date','Day'])['Hourly_Counts'].median()

# %%
footMedian
# Out:
# Date        Day
# 2018-01-01  Monday       27332.5
# 2018-01-02  Tuesday      23533.0
# 2018-01-03  Wednesday    27117.5
# 2018-01-04  Thursday     28138.5
# 2018-01-05  Friday       29075.5
#                           ...
# 2020-09-26  Saturday      3438.5
# 2020-09-27  Sunday        3356.0
# 2020-09-28  Monday        5332.0
# 2020-09-29  Tuesday       6246.5
# 2020-09-30  Wednesday     5297.5
# Name: Hourly_Counts, Length: 1004, dtype: float64

# %%
footMean = foot.groupby(['Date','Day'])['Hourly_Counts'].mean()
footMean
# Out:
# Date        Day
# 2018-01-01  Monday       25574.166667
# 2018-01-02  Tuesday      27136.250000
# 2018-01-03  Wednesday    28739.250000
# 2018-01-04  Thursday     28418.916667
# 2018-01-05  Friday       29238.375000
#                              ...
# 2020-09-26  Saturday      5025.583333
# 2020-09-27  Sunday        5764.666667
# 2020-09-28  Monday        5899.666667
# 2020-09-29  Tuesday       6169.458333
# 2020-09-30  Wednesday     5299.166667
# Name: Hourly_Counts, Length: 1004, dtype: float64

# %%
footMedian.to_csv("footfall.csv")

# %% [markdown]
# ### FINAL DATA PREPROCESSING AND EXPLORATION

# %% [markdown]
# #### YEAR - 2019

# %%
ts19 = pd.read_csv("Timeseries_2019.csv")

# %%
ts19
# Out:
#      Month  Day  Electricity_TotalDEMAND      date  max_temperature  \
# 0        1    1                193379.92    1/1/19              5.5
# 1        1    2                212941.35    2/1/19              6.6
# 2        1    3                237579.21    3/1/19              9.1
# 3        1    4                266576.92    4/1/19             11.4
# 4        1    5                194525.58    5/1/19              8.3
# ..     ...  ...                      ...       ...              ...
# 360     12   27                214512.13  27/12/19              5.8
# 361     12   28                227043.37  28/12/19              6.9
# 362     12   29                236587.05  29/12/19              8.9
# 363     12   30                280820.25  30/12/19              9.1
# 364     12   31                190820.78  31/12/19             13.1
#
#      avg_hourly_temperature  avg_temperature  min_temperature  max_humidex  \
# ...

# %%
## Checking the na values in all the columns

count = 0
for i in ts19.columns:
    if(ts19[i].isna().sum()>0):
        print(i, ":", ts19[i].isna().sum())
        count = count + 1
print(count)
# Out:
# max_temperature : 1
# avg_hourly_temperature : 88
# avg_temperature : 1
# min_temperature : 1
# max_humidex : 331
# min_windchill : 342
# max_relative_humidity : 88
# avg_hourly_relative_humidity : 88
# avg_relative_humidity : 88
# min_relative_humidity : 88
# max_dew_point : 88
# avg_hourly_dew_point : 88
# avg_dew_point : 88
# min_dew_point : 88
# max_wind_gust : 213
# wind_gust_dir_10s : 213
# max_health_index : 6
# avg_health_index : 6
# min_health_index : 6
# growdegdays_5 : 1
# growdegdays_7 : 1
# growdegdays_10 : 1
# snow_on_ground : 153
# min_uv_forecast : 31
# max_uv_forecast : 31
# solar_radiation : 365
# max_cloud_cover_4 : 365
# avg_hourly_cloud_cover_4 : 365
# avg_cloud_cover_4 : 365
# min_cloud_cover_4 : 365
# max_cloud_cover_10 : 365
# avg_hourly_cloud_cover_10 : 365
# avg_cloud_cover_10 : 365
# min_cloud_cover_10 : 365
# Unnamed: 70 : 365
# 35

# %%
for i in ts19.columns:
    if(ts19[i].isna().sum()>0):
        ts19.hist(column=i)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:185: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)

# %%
ts19.hist(column="max_temperature")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b8b9250>]],
#       dtype=object)

# %%
avg_hourly_temperature : 88
avg_hourly_relative_humidity : 88
#avg_relative_humidity : 88
avg_hourly_dew_point : 88
avg_hourly_health_index : 6
heatdegdays : 1
cooldegdays : 1

# %%
for i in ts19.columns:
    if(ts19[i].isna().sum()>0):
        ts19.hist(column=i)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/tools.py:185: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**fig_kw)

# %%
ts19.hist(column="avg_hourly_temperature")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11f96ee50>]],
#       dtype=object)

# %%
ts19.hist(column="avg_hourly_relative_humidity")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11fd81850>]],
#       dtype=object)

# %%
ts19.hist(column="avg_hourly_temperature")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11eea92d0>]],
#       dtype=object)

# %%
ts19.hist(column="avg_relative_humidity")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11edd2410>]],
#       dtype=object)

# %%
ts19.hist(column="avg_hourly_temperature")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e889dd0>]],
#       dtype=object)

# %%
ts19.hist(column="avg_hourly_dew_point")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e2d64d0>]],
#       dtype=object)

# %%
ts19.hist(column="avg_hourly_health_index")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b87c450>]],
#       dtype=object)

# %%
ts19.hist(column="heatdegdays")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11d898a50>]],
#       dtype=object)

# %%
ts19.hist(column="cooldegdays")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b66f590>]],
#       dtype=object)

# %%
#### Only for the month of september

ts19[ts19['Month']==9]['heatdegdays'].hist()

# %%
ts19[ts19['Month']==9]['heatdegdays']
# Out:
# 243    0.4
# 244    0.0
# 245    1.5
# 246    0.5
# 247    0.0
# 248    1.1
# 249    2.8
# 250    2.8
# 251    1.8
# 252    2.2
# 253    4.2
# 254    2.7
# 255    2.2
# 256    4.1
# 257    5.1
# 258    4.7
# 259    5.0
# 260    2.8
# 261    5.2
# 262    3.4
# 263    5.5
# 264    3.3
# 265    5.0
# 266    2.4
# 267    NaN
# 268    3.2
# 269    7.2
# 270    5.9
# 271    6.8
# 272    8.8
# Name: heatdegdays, dtype: float64

# %%
ts19[ts19['Month']==9]['heatdegdays'].mean()
# Out:
# 3.46896551724138

# %%
ts19[ts19['Month']==9]['cooldegdays']

# %%
ts19.hist(column = 'cooldegdays')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11af64c90>]],
#       dtype=object)

# %%
#### Filling the na values - avg_hourly_temperature

ts19['avg_hourly_temperature'].fillna(value=ts19['avg_hourly_temperature'].mean(), inplace=True)

# %%
ts19['avg_hourly_temperature'].isna().sum()
# Out:
# 0

# %%
### Average Relative humidity

ts19['avg_relative_humidity'].fillna(value=ts19['avg_relative_humidity'].median(), inplace=True)

# %%
ts19['avg_relative_humidity'].isna().sum()
# Out:
# 0

# %%
### Average Dew humidity

ts19['avg_hourly_dew_point'].fillna(value=ts19['avg_hourly_dew_point'].median(), inplace=True)

# %%
ts19['avg_hourly_dew_point'].isna().sum()
# Out:
# 0

# %%
#### avg_hourly_health_index

ts19['avg_hourly_health_index'].fillna(value=ts19['avg_hourly_health_index'].median(), inplace=True)

# %%
ts19.to_csv("Timeseries_2019.csv")

# %% [markdown]
# #### Year 2018

# %%
ts18 = pd.read_csv("Timeseries_2018.csv")

# %%
ts18
# Out:
#      Unnamed: 0  Month  Day  TOTALDEMAND        date  max_temperature  \
# 0             0      1    1    187474.30  01-01-2018              NaN
# 1             1      1    2    210555.70  02-01-2018              NaN
# 2             2      1    3    212747.65  03-01-2018              NaN
# 3             3      1    4    226675.37  04-01-2018              NaN
# 4             4      1    5    246495.47  05-01-2018              NaN
# ..          ...    ...  ...          ...         ...              ...
# 360         360     12   27    259498.28  27-12-2018              6.3
# 361         361     12   28    267662.75  28-12-2018              7.2
# 362         362     12   29    216580.22  29-12-2018             11.9
# 363         363     12   30    199227.73  30-12-2018              8.8
# 364         364     12   31    206763.83  31-12-2018              5.9
#
#      avg_hourly_temperature  avg_temperature  min_temperature  max_humidex  \
# ...

# %%
## Checking the na values in all the columns

count = 0
for i in ts18.columns:
    if(ts18[i].isna().sum()>0):
        print(i, ":", ts18[i].isna().sum())
        count = count + 1
print(count)
# Out:
# max_temperature : 10
# avg_hourly_temperature : 71
# avg_temperature : 10
# min_temperature : 10
# max_humidex : 344
# min_windchill : 342
# max_relative_humidity : 71
# avg_hourly_relative_humidity : 71
# avg_relative_humidity : 71
# min_relative_humidity : 71
# max_dew_point : 71
# avg_hourly_dew_point : 71
# avg_dew_point : 71
# min_dew_point : 71
# max_wind_speed : 10
# avg_hourly_wind_speed : 10
# avg_wind_speed : 10
# min_wind_speed : 10
# max_wind_gust : 189
# wind_gust_dir_10s : 189
# max_pressure_sea : 10
# avg_hourly_pressure_sea : 10
# avg_pressure_sea : 10
# min_pressure_sea : 10
# max_pressure_station : 10
# avg_hourly_pressure_station : 10
# avg_pressure_station : 10
# min_pressure_station : 10
# max_visibility : 10
# avg_hourly_visibility : 10
# avg_visibility : 10
# min_visibility : 10
# max_health_index : 19
# avg_hourly_health_index : 19
# avg_health_index : 19
# min_health_index : 19
# heatdegdays : 10
# cooldegdays : 10
# growdegdays_5 : 10
# growdegdays_7 : 10
# ...

# %%
ts18['avg_hourly_wind_speed'].hist()
