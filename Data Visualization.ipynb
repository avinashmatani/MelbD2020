# %%
import plotly.graph_objects as go

# Create random data with numpy
import numpy as np
np.random.seed(1)
title = 'Main Source for News'

colors = ['blue', 'red', 'green']
line_size =[1.5,1.5,1.5]
# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=x1['Date'], y=x1['scaled_social'],
                    mode='lines',
                    name='Social Distancing',connectgaps=True,line=dict(color=colors[0], width=line_size[0])))


fig.add_trace(go.Scatter(x=x1['Date'], y=x1['scaled_demand'],
                     mode='lines',
                     name='Electricity Demand',connectgaps=True,line=dict(color=colors[1], width=line_size[1])))

fig.add_trace(go.Scatter(x=x1['Date'], y=x1['scaled_cases'],
                     mode='lines',
                     name='COVID Cases Confirmed',connectgaps=True,line=dict(color=colors[2], width=line_size[2])))  
#fig.update_yaxes(range=[0.000, 1])

fig.update_layout(
    xaxis=dict(
        title="Month",
        showline=True,
        showgrid=True,
        showticklabels=True,
        linecolor='rgb(204, 204, 204)',
        linewidth=2,
        ticks='outside',
        tickfont=dict(
            family='Arial',
            size=12,
            color='rgb(82, 82, 82)',
        ),
    ),
    yaxis=dict(
        showgrid=True,
        zeroline=True,
        showline=True,
        showticklabels=False,
        title="Normalized Scale"
    ),
    autosize=True,
    margin=dict(
        autoexpand=True,
        l=100,
        r=20,
        t=110,
    ),
    showlegend=True,
    plot_bgcolor='white',
    title="Time varying relationship for factors influencing Electricity demand during Covid-19 Pandemic"
)


fig.show()
#fig1.show()
#fig2.show()
# Out:
# <div>
#
#
#             <div id="e60604c9-c354-4263-8ce0-abc2c53b6347" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e60604c9-c354-4263-8ce0-abc2c53b6347")) {
#                     Plotly.newPlot(
#                         'e60604c9-c354-4263-8ce0-abc2c53b6347',
# ...

# %%
import plotly.io as pio

# %%
pio.write_html(fig,file='index.html',auto_open=True)

# %%
import pandas as pd

x1 = pd.read_excel("Book1.xlsx")

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
obj = scaler.fit_transform(x1[['total_demand']])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
obj1 = scaler.fit_transform(x1[['Confirmed Cases']])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
obj2 = scaler.fit_transform(x1[['Social Distancing']])

# %%
x1['scaled_demand'] = obj

# %%
x1['scaled_cases'] = obj1

# %%
x1['scaled_social'] = obj2

# %%
x1.head()

# %%
import math
for i in range(len(x1)):
    if(math.isnan(float(x1['total_demand'][i]))):
        x1['total_demand'][i] = 0

# %%
x1['Social Distancing'].min()

# %%
x1['newscaled']=(x1['scaled_demand']-x1['scaled_demand'].mean())/x1['scaled_demand'].std()

# %%
x1['Social Distancing'].max()

# %%
dfnsw = pd.read_excel('nsw_pred.xlsx')

# %%
dfnsw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 3 columns):
# Date           184 non-null datetime64[ns]
# TOTALDEMAND    184 non-null float64
# Energy_pred    184 non-null float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 4.4 KB

# %%
import plotly.graph_objects as go


# Create random data with numpy
import numpy as np
np.random.seed(1)

layout = go.Layout(
    plot_bgcolor='rgba(0,0,0,0)',
    title="Actual vs Predicted Electricity Demand in NSW",
    xaxis=dict(
        title="Month"
    ),
    yaxis=dict(
        title="Demand in kWh"
    )
)
# Create traces
fig1 = go.Figure(layout=layout)
fig1.add_trace(go.Scatter(x=dfnsw['Date'], y=dfnsw['Energy_pred'],
                    mode='lines',
                    name='Energy Prediction',line=dict(color='#008080')))
fig1.add_trace(go.Scatter(x=dfnsw['Date'], y=dfnsw['TOTALDEMAND'],
                    mode='lines',
                    name='Actual Demand',line=dict(color='orange')))


fig1.show()
# Out:
# <div>
#
#
#             <div id="608126af-a348-4034-b1f2-7a746e4432d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("608126af-a348-4034-b1f2-7a746e4432d2")) {
#                     Plotly.newPlot(
#                         '608126af-a348-4034-b1f2-7a746e4432d2',
# ...

# %%
pio.write_html(fig1,file='index1.html',auto_open=True)

# %%
pio.write_html(fig2,file='index2.html',auto_open=True)

# %%
dfFinal_2020_preds = pd.read_csv('victoria_final.csv')

# %%
dfFinal_2020_preds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184 entries, 0 to 183
# Data columns (total 3 columns):
# Date           184 non-null object
# TOTALDEMAND    184 non-null float64
# Energy_pred    184 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 4.4+ KB

# %%
dfFinal_2020_preds['Date'] = pd.to_datetime(dfFinal_2020_preds['Date'])

# %%
import plotly.graph_objects as go

# Create random data with numpy
import numpy as np
np.random.seed(1)

# Create traces
layout = go.Layout(
    plot_bgcolor='rgba(0,0,0,0)',
    title="Actual vs Predicted Electricity Demand in Victoria",
    xaxis=dict(
        title="Month"
    ),
    yaxis=dict(
        title="Demand in kWh"
    )
)
fig2 = go.Figure(layout=layout)
fig2.add_trace(go.Scatter(x=dfFinal_2020_preds['Date'], y=dfFinal_2020_preds['Energy_pred'],
                    mode='lines',
                    name='Energy Prediction',line=dict(color='#008080')))
fig2.add_trace(go.Scatter(x=dfFinal_2020_preds['Date'], y=dfFinal_2020_preds['TOTALDEMAND'],
                    mode='lines',
                    name='Actual Demand',line=dict(color='orange')))

fig2.show()
# Out:
# <div>
#
#
#             <div id="54bd2a7a-2d96-434c-8cb7-bd16a616285a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("54bd2a7a-2d96-434c-8cb7-bd16a616285a")) {
#                     Plotly.newPlot(
#                         '54bd2a7a-2d96-434c-8cb7-bd16a616285a',
# ...

# %%
tls.get_embed('https://plotly.com/~ayaz/1/')
# Out:
# '<iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plotly.com/~ayaz/1.embed" height="525" width="100%"></iframe>'

# %%
tls.get_embed('https://plotly.com/~ayaz/3/')
# Out:
# '<iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plotly.com/~ayaz/3.embed" height="525" width="100%"></iframe>'

# %%
tls.get_embed('https://plotly.com/~ayaz/5/')
# Out:
# '<iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plotly.com/~ayaz/5.embed" height="525" width="100%"></iframe>'

# %%
import chart_studio
import chart_studio.tools as tls
import chart_studio.plotly as py

# %%
username='ayaz'
api_key='TsfnqRolu9e2ojY4z0lF'

# %%
chart_studio.tools.set_credentials_file(username=username,api_key=api_key)

# %%
py.plot(fig,filename='three',auto_open=False)
# Out:
# 'https://plotly.com/~ayaz/1/'

# %%
py.plot(fig1,filename='sydney',auto_open=False)
# Out:
# 'https://plotly.com/~ayaz/3/'

# %%
py.plot(fig2,filename='vic',auto_open=False)
# Out:
# 'https://plotly.com/~ayaz/5/'
